# %%
import pandas as pd
a = pd.Series([1,2,3],index=['a','b','c'])
b = pd.DataFrame([[1,2,3],[4,5,6]],index=['a','b'],columns=['c','d','e'])
print(a,'\n'*2,b,end = '\n'*2)
print(b['c'])
print(b[['c','d']])
print('*'*20)
print(b.iloc[0])
# Out:
# a    1
# b    2
# c    3
# dtype: int64
#
#     c  d  e
# a  1  2  3
# b  4  5  6
#
# a    1
# b    4
# Name: c, dtype: int64
#    c  d
# a  1  2
# b  4  5
# ********************
# c    1
# d    2
# e    3
# Name: a, dtype: int64

# %%
b['q'] = [1,2]
print(b)
b['w'] = b['q']+1
# Out:
#    c  d  e  q  w
# a  1  2  3  1  2
# b  4  5  6  2  3
