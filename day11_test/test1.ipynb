# %%
import pandas as pd
a = pd.Series([1,2,3],index=['a','b','c'])
b = pd.DataFrame([[1,2,3],[4,5,6]],index=['a','b'],columns=['c','d','e'])
print(a,'\n'*2,b)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
#
#     c  d  e
# a  1  2  3
# b  4  5  6
